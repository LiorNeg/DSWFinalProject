# %% [markdown]
# # Phase A - Collecting the Data

# %% [markdown]
# For more info see: [BBC-DataSet](https://github.com/LiorNeg/DSWFinalProject/tree/master/dataSet/bbc)

# %% [markdown]
# Connecting and downloading the dataSet

# %%
import urllib.request, urllib.parse, urllib.error
import os
url = 'http://mlg.ucd.ie/files/datasets/bbc-fulltext.zip'
directory = 'dataSet'
filename = 'dataSet/bbc-fulltext.zip'
if not os.path.exists(directory):
    os.makedirs(directory)
urllib.request.urlretrieve(url, filename)
# Out:
# ('dataSet/bbc-fulltext.zip', <http.client.HTTPMessage at 0x7fc968b6acf8>)

# %% [markdown]
# Extracting the data into 'dataSet' directory

# %%
import zipfile
zip_ref = zipfile.ZipFile(filename, 'r')
zip_ref.extractall(directory)
zip_ref.close()
if os.path.exists(filename):
    os.remove(filename)

# %% [markdown]
# Preprocessing:
# * Creating a "Class : Content" mapping

# %%
import csv
import codecs
import pandas as pd

dataMapPath = 'dataSet/data-mapping.csv'
with open(dataMapPath, 'w', newline='') as csvfile:
    fieldNames = ['Class', 'Content', 'Class_Num']
    writer = csv.DictWriter(csvfile, fieldnames=fieldNames)
    writer.writeheader()
    dataDir = 'dataSet/bbc'
    if os.path.exists(dataDir): 
        c = -1
        for d in os.listdir(dataDir):
            subdir = dataDir + '/' + d
            if not os.path.isdir(subdir):
                continue
            c += 1
            for file in os.listdir(subdir):
                filepath = subdir + '/' + file
                fd = codecs.open(filepath, 'r', encoding='utf-8', errors='ignore')
                content = fd.read()
                cleanContent = content.replace("\n\n", " ")
                writer.writerow({'Class': d, 'Content': cleanContent, 'Class_Num': c})
    dataMap = pd.read_csv(dataMapPath)

# %%
dataMap
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Class</th>
#       <th>Content</th>
#       <th>Class_Num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>business</td>
#       <td>Executive trio leave Aer Lingus Three senior e...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>business</td>
#       <td>G7 backs Africa debt relief plan G7 finance mi...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>business</td>
#       <td>Madagascar completes currency switch Madagasca...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>business</td>
#       <td>US company admits Benin bribery A US defence a...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>business</td>
#       <td>Mixed reaction to Man Utd offer Shares in Manc...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>business</td>
#       <td>US economy still growing says Fed Most areas o...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>business</td>
#       <td>DaimlerChrysler's 2004 sales rise US-German ca...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>business</td>
#       <td>WMC says Xstrata bid is too low Australian min...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>business</td>
#       <td>Brussels raps mobile call charges The European...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>business</td>
#       <td>Bank holds interest rate at 4.75% The Bank of ...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>business</td>
#       <td>McDonald's to sponsor MTV show McDonald's, the...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>business</td>
#       <td>Metlife buys up Citigroup insurer US banking g...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>business</td>
#       <td>Watchdog probes Vivendi bond sale French stock...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>business</td>
#       <td>Macy's owner buys rival for $11bn US retail gi...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>business</td>
#       <td>Industrial output falls in Japan Japanese indu...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>business</td>
#       <td>Mixed Christmas for US retailers US retailers ...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>business</td>
#       <td>BMW cash to fuel Mini production Less than fou...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>business</td>
#       <td>Ukraine revisits state sell-offs Ukraine is pr...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>business</td>
#       <td>SBC plans post-takeover job cuts US phone comp...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>business</td>
#       <td>Turkey turns on the economic charm Three years...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>business</td>
#       <td>Chinese exports rise 25% in 2004 Exports from ...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>business</td>
#       <td>Tokyo says deflation 'controlled' The Japanese...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>business</td>
#       <td>US Ahold suppliers face charges US prosecutors...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>business</td>
#       <td>Economy 'stronger than forecast' The UK econom...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>business</td>
#       <td>Renault boss hails 'great year' Strong sales o...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>business</td>
#       <td>Yukos heading back to US courts Russian oil an...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>business</td>
#       <td>Could Yukos be a blessing in disguise? Other t...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>business</td>
#       <td>Ask Jeeves tips online ad revival Ask Jeeves h...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>business</td>
#       <td>Two Nigerian banks set to merge Nigerian banks...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>business</td>
#       <td>Go-ahead for Balkan oil pipeline Albania, Bulg...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2194</th>
#       <td>entertainment</td>
#       <td>Musicians to tackle US red tape Musicians' gro...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2195</th>
#       <td>entertainment</td>
#       <td>Comic Morris returns with sitcom Comedian Chri...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2196</th>
#       <td>entertainment</td>
#       <td>Adventure tale tops awards Young book fans hav...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2197</th>
#       <td>entertainment</td>
#       <td>Rapper Jay-Z becomes label boss Rap star Jay-Z...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2198</th>
#       <td>entertainment</td>
#       <td>John Peel replacement show begins The permanen...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2199</th>
#       <td>entertainment</td>
#       <td>German music in a 'zombie' state The German mu...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2200</th>
#       <td>entertainment</td>
#       <td>Glastonbury fans to get ID cards Fans who buy ...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2201</th>
#       <td>entertainment</td>
#       <td>Portishead back after eight years Cult British...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2202</th>
#       <td>entertainment</td>
#       <td>Branson show flops on US screens Entrepreneur ...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2203</th>
#       <td>entertainment</td>
#       <td>Hobbit picture 'four years away' Lord of the R...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2204</th>
#       <td>entertainment</td>
#       <td>Eminem beats Elvis to number one Rapper Eminem...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2205</th>
#       <td>entertainment</td>
#       <td>British stars denied major Oscars British hope...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2206</th>
#       <td>entertainment</td>
#       <td>No jail for singer Courtney Love Singer Courtn...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2207</th>
#       <td>entertainment</td>
#       <td>Fry set for role in Hitchhiker's Actor Stephen...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2208</th>
#       <td>entertainment</td>
#       <td>Duran Duran show set for US TV Chart stars Dur...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2209</th>
#       <td>entertainment</td>
#       <td>Potter director signs Warner deal Harry Potter...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2210</th>
#       <td>entertainment</td>
#       <td>Star Trek fans fight to save show Star Trek fa...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2211</th>
#       <td>entertainment</td>
#       <td>Levy tipped for Whitbread prize Novelist Andre...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2212</th>
#       <td>entertainment</td>
#       <td>Johnny Depp: The acting outlaw Johnny Depp, wh...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2213</th>
#       <td>entertainment</td>
#       <td>Casino Royale is next Bond movie Casino Royale...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2214</th>
#       <td>entertainment</td>
#       <td>Wife Swap makers sue US 'copycat' The British ...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2215</th>
#       <td>entertainment</td>
#       <td>REM concerts blighted by illness US rock band ...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2216</th>
#       <td>entertainment</td>
#       <td>Brookside creator's Channel 4 bid The creator ...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2217</th>
#       <td>entertainment</td>
#       <td>Early Elvis recordings go on sale Some of Elvi...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2218</th>
#       <td>entertainment</td>
#       <td>Hanks greeted at wintry premiere Hollywood sta...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2219</th>
#       <td>entertainment</td>
#       <td>Musical treatment for Capra film The classic f...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2220</th>
#       <td>entertainment</td>
#       <td>Actor Scott is new Bond favourite Bookmaker Wi...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2221</th>
#       <td>entertainment</td>
#       <td>Snow Patrol bassist exits group Snow Patrol ha...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2222</th>
#       <td>entertainment</td>
#       <td>Sundance to honour foreign films International...</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2223</th>
#       <td>entertainment</td>
#       <td>Redford's vision of Sundance Despite sporting ...</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# <p>2224 rows × 3 columns</p>
# </div>
